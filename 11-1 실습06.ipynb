# %%
for i in range(1,101):
    if i % 3 == 0 and i % 5 ==0:
        print("3과 5의 공배수")    
    elif i % 3 == 0:
        print("3의 배수")
    elif i % 5 == 0:
        print("5의 배수")
    else:
        print(i)
# Out:
# 1
# 2
# 3의 배수
# 4
# 5의 배수
# 3의 배수
# 7
# 8
# 3의 배수
# 5의 배수
# 11
# 3의 배수
# 13
# 14
# 3과 5의 공배수
# 16
# 17
# 3의 배수
# 19
# 5의 배수
# 3의 배수
# 22
# 23
# 3의 배수
# 5의 배수
# 26
# 3의 배수
# 28
# 29
# 3과 5의 공배수
# 31
# 32
# 3의 배수
# 34
# 5의 배수
# 3의 배수
# 37
# 38
# 3의 배수
# 5의 배수
# 41
# 3의 배수
# 43
# 44
# 3과 5의 공배수
# 46
# 47
# 3의 배수
# 49
# 5의 배수
# 3의 배수
# 52
# 53
# 3의 배수
# 5의 배수
# 56
# 3의 배수
# 58
# 59
# 3과 5의 공배수
# 61
# 62
# 3의 배수
# 64
# 5의 배수
# 3의 배수
# 67
# 68
# 3의 배수
# 5의 배수
# 71
# 3의 배수
# 73
# 74
# 3과 5의 공배수
# 76
# 77
# 3의 배수
# 79
# 5의 배수
# 3의 배수
# 82
# 83
# 3의 배수
# 5의 배수
# 86
# 3의 배수
# 88
# 89
# 3과 5의 공배수
# 91
# 92
# 3의 배수
# 94
# 5의 배수
# 3의 배수
# 97
# 98
# 3의 배수
# 5의 배수
